# %% [markdown]
# <a href="https://colab.research.google.com/github/gandhigayathri10-a11y/SQL-Generator/blob/main/sql_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q gradio transformers torch black autopep8 reportlab requests

# %%
import gradio as gr
from datetime import datetime
from pathlib import Path
import json
import sqlite3
import re
import requests
import urllib.parse

# %%
schema = {
    "users": ["id","name","email","signup_date","age","country","status"],
    "orders": ["id","user_id","product_name","amount","order_date","status"],
    "products": ["id","name","price","category","stock"],
    "transactions": ["id","user_id","amount","date","type"]
}

# %%
def get_table_name(query):
    query = query.lower()

    if "user" in query:
        return "users"
    elif "order" in query:
        return "orders"
    elif "product" in query:
        return "products"
    elif "transaction" in query:
        return "transactions"
    else:
        return "users"

# %%
def generate_sql(query):

    table = get_table_name(query)

    sql = f"SELECT * FROM {table} LIMIT 10"

    return sql

# %%
def chatbot(user_input):

    sql = generate_sql(user_input)

    return "Generated SQL Query:\n" + sql

# %%
demo = gr.Interface(
    fn=chatbot,
    inputs="text",
    outputs="text",
    title="SQL Query Generator"
)

# %%
demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://578a12b001e9d0d0f4.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://578a12b001e9d0d0f4.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
